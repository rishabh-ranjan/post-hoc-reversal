# %%
import matplotlib.pyplot as plt

from fresh import *

# %%
x, y = get_data(400, 1)

# %%
fig, ax = plt.subplots()
# viz_pdf(pdf, ax)
viz_data(x, y, ax)
fig.show()

# %%
net = MLP(100)

# %%
fig, ax = plt.subplots()
viz_pdf(net, ax)
fig.show()

# %%
train(flip_frac=0.2)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 0, Loss: 0.6315942406654358
# ----------------
# Epoch 999, Loss: 0.37897932529449463
# ----------------
# Epoch 1999, Loss: 0.29973575472831726
# ----------------
# Epoch 2999, Loss: 0.14647547900676727
# ----------------
# Epoch 3999, Loss: 0.19700567424297333
# ----------------
# Epoch 4999, Loss: 0.05850621685385704
# ----------------
# Epoch 5999, Loss: 0.37401553988456726
# ----------------
# Epoch 6999, Loss: 0.032046739012002945
# ----------------
# Epoch 7999, Loss: 0.0938231348991394
# ----------------
# Epoch 8999, Loss: 0.09819295257329941
# ----------------
# Epoch 9999, Loss: 0.22277353703975677
# ----------------
