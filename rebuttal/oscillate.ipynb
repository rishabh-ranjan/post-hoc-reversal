# %% [markdown]
# ## Example Notebook: Epoch-Wise Post-Hoc Reversal on CIFAR-N

# %% [markdown]
# This notebook reproduces the epoch-wise post-hoc reversal curves for CIFAR-N (Figure 1 in the paper), modulo styling.

# %% [markdown]
# Other datasets are similar, except that they don't have the `--noise` argument (they are naturally noisy).

# %% [markdown]
# ### Experimental Runs

# %% [markdown]
# #### Setup

# %%
import os

import matplotlib.pyplot as plt
import pandas as pd

from expt.utils import KeyValStore

# "cifar10", "cifar100_coarse", or "cifar100_fine"
os.environ["DATASET"] = "cifar10"

# "clean", "aggregate", "random1", "random2", "random3", or "worst" for cifar10
# "clean" or "noisy" for cifar100_coarse and cifar100_fine
os.environ["NOISE"] = "worst"

# number of models to train for ensembling
os.environ["ENSEMBLE_SIZE"] = "8"

# name of wandb project
# use "''" to skip wandb logging
# os.environ["WANDB"] = "post-hoc-reversal"
os.environ["WANDB"] = "''"

# %% [markdown]
# Running for the first time downloads and prepares the data.

# %%
# %%bash
# python -m expt.cifar --root out/dummy --wandb '' --dataset $DATASET --noise $NOISE --num-epochs 0
# Out:
# args=Namespace(root='out/dummy', wandb='', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=0, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476

# %% [markdown]
# #### Base (no transform) and SWA

# %% [markdown]
# Train `$ENSEMBLE_SIZE` models in parallel with default hyperparameters.
# Use `python -m expt.cifar --help` for options.

# %% [markdown]
# This assumes `$ENSEMBLE_SIZE` GPUs are available.
# For CPU-only environments, use `export CUDA_VISIBLE_DEVICES=''`.
# For single-GPU environments, use `export CUDA_VISIBLE_DEVICES=0`.
# For sequential execution, e.g. to prevent memory issues on a single GPU, remove the `&`.

# %% [markdown]
# On a _Quadro RTX 8000_ GPU, each run takes around 3 minutes.

# %% [markdown]
# This records the Base (no transform) and SWA checkpoints for every epoch.

# %%
# %%bash
# for i in $(seq 1 $ENSEMBLE_SIZE)
# do
#     export CUDA_VISIBLE_DEVICES=$((i-1))
#     # python -m expt.cifar --root out/idv$i --wandb $WANDB --dataset $DATASET --noise $NOISE &
#     python -m expt.cifar --root out/idv$i --dataset $DATASET --noise $NOISE &
# done
# wait
# Out:
# args=Namespace(root='out/idv5', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv5'
# args=Namespace(root='out/idv3', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv3'
# args=Namespace(root='out/idv6', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv6'
# args=Namespace(root='out/idv2', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv2'
# args=Namespace(root='out/idv1', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv1'
# args=Namespace(root='out/idv7', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv7'
# args=Namespace(root='out/idv8', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv8'
# args=Namespace(root='out/idv4', wandb='2023-08-23', dataset='cifar10', noise='worst', eval_batch_size=1000, train_batch_size=500, model='resnet18d', pretrained=True, width=64, optimizer='sgd', lr=0.1, momentum=0.9, weight_decay=0.0005, scheduler='cosine', num_epochs=100, amp=True, loss='ce', sop_lr_u=10.0, sop_lr_v=100.0, elr_momentum=0.9, elr_weight=1.0)
# num_classes=10
# len(X['train'])=40000
# len(X['val'])=5000
# len(X['test'])=5000
# max class freq: 0.12105999886989594
# min class freq: 0.08079999685287476
# run.name='cifar10__worst__idv4'

# %% [markdown]
# #### Temperature Scaling

# %% [markdown]
# Now we calibrate (temperature-scale) the Base and SWA checkpoints for every epoch. On a _Quadro RTX 8000_ GPU this takes around 20s.

# %%
# %%bash
# for i in $(seq 1 $ENSEMBLE_SIZE)
# do
#     export CUDA_VISIBLE_DEVICES=$((i-1))
#     python -m expt.calibrate --root out/idv$i --wandb $WANDB --base base &
#     python -m expt.calibrate --root out/idv$i --wandb $WANDB --base base+swa &
# done
# wait
# Out:
# args=Namespace(root='out/idv7', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv3', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv6', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv2', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv4', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv3', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv4', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv8', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv7', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv8', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv5', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv5', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv2', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv1', wandb="''", base='base', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv1', wandb="''", base='base+swa', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/idv6', wandb="''", base='base', cal='temp_scaler', suf='ts')
# wandb: 🚀 View run base+ts__idv7 at: https://wandb.ai/rishabh-ranjan/''/runs/nofnly22
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175936-nofnly22/logs
# wandb: 🚀 View run base+swa+ts__idv6 at: https://wandb.ai/rishabh-ranjan/''/runs/dvnqgxlo
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-dvnqgxlo/logs
# wandb: 🚀 View run base+swa+ts__idv7 at: https://wandb.ai/rishabh-ranjan/''/runs/alzx1zxp
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175940-alzx1zxp/logs
# epochs:  37%|███████████████▏                         | 37/100 [00:48<00:51,  1.23it/s]
# wandb: 🚀 View run base+swa+ts__idv1 at: https://wandb.ai/rishabh-ranjan/''/runs/40ehohie
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-40ehohie/logs
# wandb: 🚀 View run base+ts__idv1 at: https://wandb.ai/rishabh-ranjan/''/runs/1f853xe0
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-1f853xe0/logs
# wandb: 🚀 View run base+swa+ts__idv5 at: https://wandb.ai/rishabh-ranjan/''/runs/li8bt27e
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-li8bt27e/logs
# wandb: 🚀 View run base+ts__idv5 at: https://wandb.ai/rishabh-ranjan/''/runs/vya8jt4v
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-vya8jt4v/logs
# wandb: 🚀 View run base+ts__idv6 at: https://wandb.ai/rishabh-ranjan/''/runs/2zd4c7cz
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-2zd4c7cz/logs
# wandb: 🚀 View run base+swa+ts__idv2 at: https://wandb.ai/rishabh-ranjan/''/runs/9i971a9s
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-9i971a9s/logs
# wandb: 🚀 View run base+ts__idv3 at: https://wandb.ai/rishabh-ranjan/''/runs/a5uxkezg
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-a5uxkezg/logs
# epochs:  94%|██████████████████████████████████████▌  | 94/100 [01:08<00:00,  7.38it/s]
# wandb: 🚀 View run base+swa+ts__idv4 at: https://wandb.ai/rishabh-ranjan/''/runs/2p2nq0in
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-2p2nq0in/logs
# wandb: 🚀 View run base+swa+ts__idv3 at: https://wandb.ai/rishabh-ranjan/''/runs/av7hxcjb
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-av7hxcjb/logs
# wandb: 🚀 View run base+ts__idv2 at: https://wandb.ai/rishabh-ranjan/''/runs/kob555tf
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-kob555tf/logs
# wandb: 🚀 View run base+ts__idv8 at: https://wandb.ai/rishabh-ranjan/''/runs/1mb4ey5a
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175941-1mb4ey5a/logs
# wandb: 🚀 View run base+ts__idv4 at: https://wandb.ai/rishabh-ranjan/''/runs/uk2a6lpe
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175939-uk2a6lpe/logs
# wandb: 🚀 View run base+swa+ts__idv8 at: https://wandb.ai/rishabh-ranjan/''/runs/9g9w7nia
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_175940-9g9w7nia/logs

# %% [markdown]
# #### Ensembling

# %% [markdown]
# Next, we ensemble the base models and all compositions of post-hoc transforms we have so far, per epoch. On a _Quadro RTX 8000_ GPU this takes around 20s. Note that _"ensemble"_ in the paper actually refers to `ts+ens` in the code.

# %%
# %%bash
# for s in val test train_true train_false
# do
#     for b in base base+swa base+ts base+swa+ts
#     do
#         python -m expt.ensemble --root out/ens$ENSEMBLE_SIZE --wandb $WANDB --runs out/idv* --split $s --base $b &
#     done
# done
# wait
# Out:
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_false', base='base+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='val', base='base+swa')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='test', base='base+swa+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='val', base='base')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='val', base='base+swa+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_false', base='base+swa+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='test', base='base+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='test', base='base')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='test', base='base+swa')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_true', base='base+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_false', base='base+swa')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_false', base='base')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_true', base='base')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='val', base='base+ts')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_true', base='base+swa')
# args=Namespace(root='out/ens8', wandb="''", runs=['out/idv1', 'out/idv2', 'out/idv3', 'out/idv4', 'out/idv5', 'out/idv6', 'out/idv7', 'out/idv8'], split='train_true', base='base+swa+ts')
# wandb: 🚀 View run base+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/6e4pyhu2
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180757-6e4pyhu2/logs
# wandb: 🚀 View run base+swa+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/h3f6cs4b
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180757-h3f6cs4b/logs
# wandb: 🚀 View run base+swa+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/15z9bpuc
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180757-15z9bpuc/logs
# wandb: 🚀 View run base+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/xnyr7ng1
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180759-xnyr7ng1/logs
# wandb: 🚀 View run base+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/fl2w8x59
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180759-fl2w8x59/logs
# wandb: 🚀 View run base+swa+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/1fuq2ktg
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180759-1fuq2ktg/logs
# wandb: 🚀 View run base+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/pzsboe34
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-pzsboe34/logs
# wandb: 🚀 View run base+swa+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/annab834
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180800-annab834/logs
# wandb: 🚀 View run base+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/5jd7b0kz
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-5jd7b0kz/logs
# wandb: 🚀 View run base+swa+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/n7c30kfr
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180759-n7c30kfr/logs
# wandb: 🚀 View run base+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/803jyuc1
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-803jyuc1/logs
# wandb: 🚀 View run base+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/icy7o1s2
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-icy7o1s2/logs
# wandb: 🚀 View run base+swa+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/mro6nmbu
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-mro6nmbu/logs
# wandb: 🚀 View run base+swa+ts+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/swngp1gc
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-swngp1gc/logs
# wandb: 🚀 View run base+swa+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/ruzuvlv6
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-ruzuvlv6/logs
# wandb: 🚀 View run base+ens__ens8 at: https://wandb.ai/rishabh-ranjan/''/runs/pcdb1jvi
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180802-pcdb1jvi/logs

# %% [markdown]
# Finally, we calibrate the ensembles (again, for every epoch). On a _Quadro RTX 8000_ GPU this takes around 20s.

# %%
# %%bash
# for b in base+ens base+swa+ens base+ts+ens base+swa+ts+ens
# do
#     # python -m expt.calibrate --root out/ens$ENSEMBLE_SIZE --wandb $WANDB --base $b &
#     python -m expt.calibrate --root out/ens$ENSEMBLE_SIZE --base $b &
# done
# wait
# Out:
# args=Namespace(root='out/ens8', wandb='2023-07-28', base='base+swa+ens', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/ens8', wandb='2023-07-28', base='base+swa+ts+ens', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/ens8', wandb='2023-07-28', base='base+ens', cal='temp_scaler', suf='ts')
# args=Namespace(root='out/ens8', wandb='2023-07-28', base='base+ts+ens', cal='temp_scaler', suf='ts')
# wandb: 🚀 View run base+swa+ens+ts__ens8 at: https://wandb.ai/rishabh-ranjan/2023-07-28/runs/ejpn0f4n
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180831-ejpn0f4n/logs
# wandb: 🚀 View run base+ts+ens+ts__ens8 at: https://wandb.ai/rishabh-ranjan/2023-07-28/runs/f0333n47
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180832-f0333n47/logs
# wandb: 🚀 View run base+swa+ts+ens+ts__ens8 at: https://wandb.ai/rishabh-ranjan/2023-07-28/runs/y9nbgttk
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180832-y9nbgttk/logs
# wandb: 🚀 View run base+ens+ts__ens8 at: https://wandb.ai/rishabh-ranjan/2023-07-28/runs/z738bt1a
# wandb: Find logs at: ../../../../../../afs/cs.stanford.edu/u/ranjanr/.cache/wandb/run-20240806_180832-z738bt1a/logs

# %% [markdown]
# ### Plots for Post-Hoc Reversal

# %%
def draw(ax, kv):
    scale = 1

    x = kv.load("epochs")

    Y = kv.load(f"osc/train_true/base") * scale
    y = Y.mean(0)
    ax.plot(x, y, label="Correctly labeled training points")

    Y = kv.load(f"osc/train_false/base") * scale
    y = Y.mean(0)
    ax.plot(x, y, label="Mis-labeled training points")
    
    ax.legend()

    ax.set_xlabel("Epochs")
    ax.set_ylabel("Fraction of points where\nprediction changed from last epoch's")

    ax.set_ylim(0, 1)

# %%
kv = KeyValStore(f"out/ens{os.environ['ENSEMBLE_SIZE']}")

# %%
fig, ax = plt.subplots()
draw(ax, kv)
fig.show()

# %%
fig, ax = plt.subplots()
draw(ax, kv, split="train_false")
ax.set_title("Mis-labeled training points") 
fig.show()

# %% [markdown]
# ### Table for Post-Hoc Selection

# %%
# %%bash
# python -m expt.select --root out/ens$ENSEMBLE_SIZE
# Out:
# args=Namespace(root='out/ens4', bases=['base', 'base+swa', 'base+ts', 'base+swa+ts', 'base+ens', 'base+swa+ens', 'base+ts+ens', 'base+swa+ts+ens', 'base+ens+ts', 'base+swa+ens+ts', 'base+ts+ens+ts', 'base+swa+ts+ens+ts'])

# %%
kv = KeyValStore(f"out/ens{os.environ['ENSEMBLE_SIZE']}")

# %% [markdown]
# Here we reproduce the post-hoc selection vs naive selection results from Table 1 in the paper. When possible, we show mean +- std.

# %%
txt = {
    "nll": "Test Loss",
    "err": "Test Error (%)",
    "base": "No Transform",
    "base+swa+ts": "SWA+TS",
    "base+swa+ts+ens+ts": "SWA+Ens+TS",
    "pre": "Naive",
    "post": "Ours",
}

# %%
rec = {}
for metric in ["nll", "err"]:
    scale = 100 if metric == "err" else 1
    fmt = ".2f" if metric == "err" else ".3f"

    for tr in ["base", "base+swa+ts", "base+swa+ts+ens+ts"]:
        for sel in ["pre", "post"]:
            key = (txt[metric], txt[tr], txt[sel])
            kv_key = f"sel={sel}/obj={metric}/{metric}/test/{tr}"
            kv_val = kv.load(kv_key).float() * scale
            if "ens" in tr:
                val = f"{kv_val.item():{fmt}}"
            else:
                val = f"{kv_val.mean().item():{fmt}}$\\pm${kv_val.std().item():{fmt}}"
            rec[key] = [val]
pd.DataFrame(rec)
# Out:
#          Test Loss                                                     \
#       No Transform                            SWA+TS
#              Naive             Ours            Naive             Ours
# 0  1.508$\pm$0.015  1.508$\pm$0.015  1.489$\pm$0.012  1.445$\pm$0.006
#
#                      Test Error (%)                                  \
#   SWA+Ens+TS           No Transform                          SWA+TS
#        Naive   Ours           Naive            Ours           Naive
# 0      1.450  1.407  46.98$\pm$0.80  46.98$\pm$0.80  46.46$\pm$0.88
#
#
#                   SWA+Ens+TS
#              Ours      Naive   Ours
# 0  44.15$\pm$0.15      44.98  43.16
