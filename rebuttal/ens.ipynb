# %%
import matplotlib.pyplot as plt
from ens import *

# %%
x, y, xt, yt = get_data()

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, cmap="coolwarm")

# %%
plt.scatter(xt[:, 0], xt[:, 1], c=yt, cmap="coolwarm")
